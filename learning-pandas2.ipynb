# %%
import pandas as pd

# %%
df = pd.read_csv("data/daily_report.csv")
df.head()
# Out:
#    FIPS Admin2 Province_State Country_Region          Last_Update       Lat  \
# 0   NaN    NaN            NaN    Afghanistan  2021-03-02 05:23:30  33.93911
# 1   NaN    NaN            NaN        Albania  2021-03-02 05:23:30  41.15330
# 2   NaN    NaN            NaN        Algeria  2021-03-02 05:23:30  28.03390
# 3   NaN    NaN            NaN        Andorra  2021-03-02 05:23:30  42.50630
# 4   NaN    NaN            NaN         Angola  2021-03-02 05:23:30 -11.20270
#
#        Long_  Confirmed  Deaths  Recovered   Active Combined_Key  \
# 0  67.709953      55733    2444      49344   3945.0  Afghanistan
# 1  20.168300     107931    1816      70413  35702.0      Albania
# 2   1.659600     113255    2987      78234  32034.0      Algeria
# 3   1.521800      10889     110      10475    304.0      Andorra
# 4  17.873900      20854     508      19400    946.0       Angola
#
#    Incident_Rate  Case_Fatality_Ratio
# 0     143.168187             4.385194
# 1    3750.469108             1.682556
# ...

# %%
# > 데이터 프레임으로 부터 원하는 컬럼을 뽑아낼때, [[]]처럼 이중 리스트안에 처리하면, 데이터 형식이 데이터프레임 그대로 나오게 된다.
# 반대로 리스트한쌍만으로 감싸면, 데이터 형식은 시리즈가 된다.

country = df[["Country_Region"]]
data = df[["Confirmed","Deaths","Recovered"]]

#total = country.merge(data)
total = pd.concat([country, data], axis=1)
total
# Out:
#           Country_Region  Confirmed  Deaths  Recovered
# 0            Afghanistan      55733    2444      49344
# 1                Albania     107931    1816      70413
# 2                Algeria     113255    2987      78234
# 3                Andorra      10889     110      10475
# 4                 Angola      20854     508      19400
# ...                  ...        ...     ...        ...
# 3976             Vietnam       2448      35       1876
# 3977  West Bank and Gaza     185336    2058     167744
# 3978               Yemen       2310     634       1435
# 3979              Zambia      79002    1098      75087
# 3980            Zimbabwe      36115    1468      32905
#
# [3981 rows x 4 columns]

# %%
df[df["Country_Region"] == "Vietnam"]
# Out:
#       FIPS Admin2 Province_State Country_Region          Last_Update  \
# 3976   NaN    NaN            NaN        Vietnam  2021-03-02 05:23:30
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 3976  14.058324  108.277199       2448      35       1876   537.0
#
#      Combined_Key  Incident_Rate  Case_Fatality_Ratio
# 3976      Vietnam       2.514933             1.429739

# %%
df.loc[df["Confirmed"] > 100000]
by_sort = df[df["Deaths"] > 10000]
by_sort.sort_values(by=["Deaths"], ascending=False)
# Out:
#         FIPS       Admin2       Province_State  Country_Region  \
# 3961     NaN          NaN              England  United Kingdom
# 216      NaN          NaN                  NaN          France
# 287      NaN          NaN                  NaN            Iran
# 65       NaN          NaN            Sao Paulo          Brazil
# 269      NaN          NaN          Maharashtra           India
# 6        NaN          NaN                  NaN       Argentina
# 595      NaN          NaN                  NaN    South Africa
# 491      NaN          NaN                  NaN          Poland
# 286      NaN          NaN                  NaN       Indonesia
# 61       NaN          NaN       Rio de Janeiro          Brazil
# 402      NaN          NaN               Mexico          Mexico
# 651      NaN          NaN                  NaN          Turkey
# 299      NaN          NaN            Lombardia           Italy
# 394      NaN          NaN     Ciudad de Mexico          Mexico
# ...
